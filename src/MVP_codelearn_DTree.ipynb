# %% [markdown]
# ## Part (a)
# Import the data and save the data into a variable `X` and the targets into a variable `Y`.

# %%
# Import suitable packages, load the dataset, and save data and targets into variables X and Y
# import packages
##TODO##
import numpy as np
import matplotlib.pyplot as plt
import json
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
# %matplotlib inline

# %% [markdown]
# Load the data

# %%
path2 = "/content/drive/MyDrive/MVP/Airbus_Part_numbersDTree.csv"
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_part = pd.read_csv(path2)
print(df_part)
#print(df_part.head())
print(df_part.iloc[:,0])
print(df_part.iloc[:,1])
print(df_part.shape)
# Out:
#                   Code  Status  encoded_code  Unnamed: 3  Unnamed: 4  \
# 0           8817VB 95M    True            98         NaN          10
# 1           3968VB 97M    True            52         NaN          10
# 2           7456VB 36M    True            88         NaN          10
# 3           3001VB 20M    True            35         NaN          10
# 4           3914VB 17M    True            51         NaN          10
# ..                 ...     ...           ...         ...         ...
# 328  V52895437068-BS99   False           111         NaN          17
# 329  V92895437068-BS90   False           320         NaN          17
# 330  V92894437068-BS99   False           316         NaN          17
# 331  V92895436068-BS99   False           318         NaN          17
# 332  V92895435099-BS99   False           317         NaN          17
#
#      Unnamed: 5  Count of types of string  part_class
# 0          10.0                     102.0           2
# 1           9.0                       9.0           2
# 2          12.0                     111.0           2
# 3          17.0                     102.0           2
# 4          16.0                       9.0           2
# ..          ...                       ...         ...
# 328         NaN                       NaN           5
# 329         NaN                       NaN           5
# 330         NaN                       NaN           5
# 331         NaN                       NaN           5
# 332         NaN                       NaN           5
#
# [333 rows x 8 columns]
# 0             8817VB 95M
# 1             3968VB 97M
# 2             7456VB 36M
# 3             3001VB 20M
# 4             3914VB 17M
#              ...
# 328    V52895437068-BS99
# 329    V92895437068-BS90
# 330    V92894437068-BS99
# 331    V92895436068-BS99
# 332    V92895435099-BS99
# Name: Code, Length: 333, dtype: object
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# Name: Status, Length: 333, dtype: bool
# (333, 8)

# %%
# path3 = "/content/drive/MyDrive/MVP/Airbus_Part_numbersML.csv"  #save file
# df_part.to_csv(path3, index=False)

# %% [markdown]
# Feature Extraction Function

# %%
def extract_features(string):
    return {
        'contains_space': ' ' in string,
        'contains_hyphen': '-' in string,
        'pos0_isalpha': string[0].isalpha(),
        'pos4_isalpha': string[4].isalpha() if len(string) > 4 else False,
        'pos0_V': string[0] == 'V' if len(string) > 0 else False,
        'pos1_9': string[1:9].isdigit() if len(string) > 9 else False,  # Checks if characters 1 to 8 are digits
        'pos13': string[13] == 'B' if len(string) > 13 else False,
        'pos14': string[14] == 'S' if len(string) > 13 else False
    }

# Apply feature extraction
df_features = df_part['Code'].apply(lambda x: pd.Series(extract_features(x)))

# %%
path4 = "/content/drive/MyDrive/MVP/Airbus_Part_numbers_Features.csv"  #save file
df_features.to_csv(path4)

# %%
X = df_features  # Features
y = df_part['part_class']  # Target class labels

# %% [markdown]
# ## Part (b)
#
# Splt data 80:20

# %%
# Import the package train_test_split from sklearn.model_selection.
# Split the dataset into Xtr, Xtest, Ytr, Ytest. Xtest and Ytest will form your held-out
# test set. You will later split Xtr and Ytr into training and validation sets.
from sklearn.model_selection import train_test_split

# The function returns splits of each array passed in.
# The proportion to be used as the training set is given by test_size
Xtr, Xtest, ytr, ytest = train_test_split (X, y, test_size=0.2,random_state=10)

#print(Xtr.shape, Xtest.shape)
#print(ytr.shape, ytest.shape)
# print(ytr[0:2])
# print(Xtr[3])
# print(np.linalg.norm(Xtr[3] - Xtr[5]))
#print(len(Xtr))
print(Xtr,Xtest)
#print(ytr,ytest)
print(Xtr.shape,Xtest.shape)
# Out:
#      contains_space  contains_hyphen  pos0_isalpha  pos4_isalpha  pos0_V  \
# 59             True            False         False          True   False
# 37             True            False         False          True   False
# 173           False            False          True         False    True
# 189           False            False          True         False    True
# 148           False            False          True         False    True
# ..              ...              ...           ...           ...     ...
# 123           False            False          True         False    True
# 320            True            False         False          True   False
# 15             True            False         False          True   False
# 125           False            False          True         False    True
# 265           False             True          True         False    True
#
#      pos1_9  pos13  pos14
# 59    False  False  False
# 37    False  False  False
# 173    True  False  False
# 189    True  False  False
# 148    True  False  False
# ..      ...    ...    ...
# 123    True  False  False
# 320   False  False  False
# 15    False  False  False
# 125    True  False  False
# 265    True   True   True
#
# [266 rows x 8 columns]      contains_space  contains_hyphen  pos0_isalpha  pos4_isalpha  pos0_V  \
# 43             True            False         False          True   False
# 266           False             True          True         False    True
# 157           False            False          True         False    True
# 325           False             True          True         False    True
# 227           False             True          True         False    True
# ..              ...              ...           ...           ...     ...
# 25             True            False         False          True   False
# 154           False            False          True         False    True
# 229           False             True          True         False    True
# 222           False             True          True         False    True
# 213           False             True          True         False    True
#
#      pos1_9  pos13  pos14
# 43    False  False  False
# 266    True   True   True
# 157    True  False  False
# 325    True   True   True
# 227    True   True   True
# ..      ...    ...    ...
# 25    False  False  False
# 154    True  False  False
# 229    True   True   True
# 222    True   True   True
# 213    True   True   True
#
# [67 rows x 8 columns]
# (266, 8) (67, 8)

# %% [markdown]
# ## Part (c)
# Use library, and test against training data.

# %% [markdown]
# Check whether your predictions are the same as the predictions from `KNeighborsClassifier`.

# %%
DT = DecisionTreeClassifier(max_depth=5)
DT.fit(Xtr, ytr)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
y_pred_DT = DT.predict(Xtest)

# %%
print("DT_knn_test =", accuracy_score(y_pred_DT, ytest))  #accuracy score
#print(list(zip(Xtest, y_pred_DT)))
print(ytest)
print(y_pred_DT)
print(len(y_pred_DT))
# Out:
# DT_knn_test = 0.9104477611940298
# 43     2
# 266    5
# 157    3
# 325    5
# 227    5
#       ..
# 25     2
# 154    3
# 229    5
# 222    5
# 213    5
# Name: part_class, Length: 67, dtype: int64
# [2 5 3 5 5 2 3 2 3 5 2 3 3 2 5 3 2 5 2 5 2 3 5 2 5 3 2 3 3 2 3 5 5 2 3 3 2
#  2 5 5 3 5 2 3 3 5 5 5 2 2 3 2 3 5 5 2 2 3 3 3 5 3 2 3 5 5 5]
# 67

# %%
y_prob = DT.predict_proba(Xtest)
print(np.max(y_prob, axis=1), y_pred_DT)
print(ytest[0:67])
# Out:
# [0.93333333 0.93181818 1.         0.93181818 0.93181818 0.93333333
#  1.         0.93333333 1.         0.93181818 0.93333333 1.
#  1.         0.93333333 0.93181818 1.         0.93333333 0.93181818
#  0.93333333 0.93181818 0.93333333 1.         0.93181818 0.93333333
#  0.93181818 1.         0.93333333 1.         1.         0.93333333
#  1.         0.93181818 0.93181818 0.93333333 1.         1.
#  0.93333333 0.93333333 0.93181818 0.93181818 1.         0.93181818
#  0.93333333 1.         1.         0.93181818 0.93181818 0.93181818
#  0.93333333 0.93333333 1.         0.93333333 1.         0.93181818
#  0.93181818 0.93333333 0.93333333 1.         1.         1.
#  0.93181818 1.         0.93333333 1.         0.93181818 0.93181818
#  0.93181818] [2 5 3 5 5 2 3 2 3 5 2 3 3 2 5 3 2 5 2 5 2 3 5 2 5 3 2 3 3 2 3 5 5 2 3 3 2
#  2 5 5 3 5 2 3 3 5 5 5 2 2 3 2 3 5 5 2 2 3 3 3 5 3 2 3 5 5 5]
# 43     2
# 266    5
# 157    3
# 325    5
# 227    5
#       ..
# 25     2
# 154    3
# 229    5
# 222    5
# 213    5
# Name: part_class, Length: 67, dtype: int64

# %%
new_strings = pd.Series(['8817VB 95M', 'W9296S000', 'V92369097810-BS99', 'V923690810-BS11'])
new_features = new_strings.apply(lambda x: pd.Series(extract_features(x)))
new_pred = DT.predict(new_features)
print(list(zip(new_strings, new_pred)))
new_prob = DT.predict_proba(new_features)
print(np.max(np.where(new_prob < 1, new_prob, np.nan), axis=1))
# Out:
# [('8817VB 95M', 2), ('W9296S000', 3), ('V92369097810-BS99', 5), ('V923690810-BS11', 3)]
# [0.93333333        nan 0.93181818        nan]
